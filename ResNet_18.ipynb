# %%
import tensorflow as tf
from tensorflow.keras import layers,models

# %%
def residual_block(inputs,filters,downsample=False):
  # The residual block consists of two convolutional layers with batch normalization and ReLU activation.
  conv_1 = layers.Conv2D(filters=filters,kernel_size=(3,3),strides=1 if not downsample else 2,padding='same')(inputs)
  bn_1 = layers.BatchNormalization()(conv_1)
  relu_1 = layers.Activation('relu')(bn_1)

  conv_2 = layers.Conv2D(filters=filters,kernel_size=(3,3),padding='same')(relu_1)
  bn_2 = layers.BatchNormalization()(conv_2)
  # If downsample is True, we apply a 1x1 convolution and downsample the inputs.
  if downsample:
    inputs=layers.Conv2D(filters=filters,kernel_size=(1,1),strides=2,padding='same')(inputs)
  res_add = layers.Add()([bn_2,inputs])
  relu_2 = layers.Activation('relu')(res_add)
  return relu_2

# %%
def resnet_18(input_shape, num_classes,activation):
    input_layer = tf.keras.layers.Input(shape=input_shape)

    # Initial convolutional layer
    conv_1 =  layers.Conv2D(64, kernel_size=(7, 7), strides=2, padding='same')(input_layer)
    bn_1 =  layers.BatchNormalization()(conv_1)
    relu_1 =  layers.Activation('relu')(bn_1)
    max_pool_1 =  layers.MaxPooling2D(pool_size=(3, 3), strides=2, padding='same')(relu_1)

    # Residual blocks
    res_1 = residual_block(inputs=max_pool_1, filters=64)
    res_2 = residual_block(inputs=res_1,filters= 64)
    res_3 = residual_block(inputs=res_2, filters=128, downsample=True)
    res_4 = residual_block(inputs=res_3, filters=128)
    res_5 = residual_block(inputs=res_4, filters=256, downsample=True)
    res_6 = residual_block(inputs=res_5, filters=256)
    res_7 = residual_block(inputs=res_6, filters=512, downsample=True)
    res_8 = residual_block(inputs=res_7, filters=512)

    # Global average pooling and classification layer
    global_avg_pool  =  layers.GlobalAveragePooling2D()(res_8)
    output_layer =  layers.Dense(num_classes, activation=activation)(global_avg_pool)

    model = models.Model(inputs=input_layer, outputs=output_layer)
    return model

# Example usage
input_shape = (224, 224, 3)  # Input shape of the images (assuming 224x224 RGB images)
num_classes = 20  # Number of output classes for the classification task
activation = 'softmax'
resnet18_model = resnet_18(input_shape, num_classes,activation)
resnet18_model.summary()
# Out:
# Model: "model_10"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_12 (InputLayer)          [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_201 (Conv2D)            (None, 112, 112, 64  9472        ['input_12[0][0]']
#                                 )
#
#  batch_normalization_177 (Batch  (None, 112, 112, 64  256        ['conv2d_201[0][0]']
#  Normalization)                 )
#
#  activation_176 (Activation)    (None, 112, 112, 64  0           ['batch_normalization_177[0][0]']
#                                 )
#
#  max_pooling2d_11 (MaxPooling2D  (None, 56, 56, 64)  0           ['activation_176[0][0]']
#  )
#
#  conv2d_202 (Conv2D)            (None, 56, 56, 64)   36928       ['max_pooling2d_11[0][0]']
#
#  batch_normalization_178 (Batch  (None, 56, 56, 64)  256         ['conv2d_202[0][0]']
#  Normalization)
#
#  activation_177 (Activation)    (None, 56, 56, 64)   0           ['batch_normalization_178[0][0]']
#
#  conv2d_203 (Conv2D)            (None, 56, 56, 64)   36928       ['activation_177[0][0]']
#
#  batch_normalization_179 (Batch  (None, 56, 56, 64)  256         ['conv2d_203[0][0]']
#  Normalization)
#
#  add_83 (Add)                   (None, 56, 56, 64)   0           ['batch_normalization_179[0][0]',
#                                                                   'max_pooling2d_11[0][0]']
#
#  activation_178 (Activation)    (None, 56, 56, 64)   0           ['add_83[0][0]']
#
#  conv2d_204 (Conv2D)            (None, 56, 56, 64)   36928       ['activation_178[0][0]']
#
#  batch_normalization_180 (Batch  (None, 56, 56, 64)  256         ['conv2d_204[0][0]']
#  Normalization)
#
#  activation_179 (Activation)    (None, 56, 56, 64)   0           ['batch_normalization_180[0][0]']
#
#  conv2d_205 (Conv2D)            (None, 56, 56, 64)   36928       ['activation_179[0][0]']
#
#  batch_normalization_181 (Batch  (None, 56, 56, 64)  256         ['conv2d_205[0][0]']
#  Normalization)
#
#  add_84 (Add)                   (None, 56, 56, 64)   0           ['batch_normalization_181[0][0]',
#                                                                   'activation_178[0][0]']
#
#  activation_180 (Activation)    (None, 56, 56, 64)   0           ['add_84[0][0]']
#
#  conv2d_206 (Conv2D)            (None, 28, 28, 128)  73856       ['activation_180[0][0]']
#
#  batch_normalization_182 (Batch  (None, 28, 28, 128)  512        ['conv2d_206[0][0]']
#  Normalization)
#
#  activation_181 (Activation)    (None, 28, 28, 128)  0           ['batch_normalization_182[0][0]']
#
#  conv2d_207 (Conv2D)            (None, 28, 28, 128)  147584      ['activation_181[0][0]']
#
#  batch_normalization_183 (Batch  (None, 28, 28, 128)  512        ['conv2d_207[0][0]']
#  Normalization)
#
#  conv2d_208 (Conv2D)            (None, 28, 28, 128)  8320        ['activation_180[0][0]']
#
#  add_85 (Add)                   (None, 28, 28, 128)  0           ['batch_normalization_183[0][0]',
#                                                                   'conv2d_208[0][0]']
#
#  activation_182 (Activation)    (None, 28, 28, 128)  0           ['add_85[0][0]']
#
#  conv2d_209 (Conv2D)            (None, 28, 28, 128)  147584      ['activation_182[0][0]']
#
#  batch_normalization_184 (Batch  (None, 28, 28, 128)  512        ['conv2d_209[0][0]']
#  Normalization)
#
#  activation_183 (Activation)    (None, 28, 28, 128)  0           ['batch_normalization_184[0][0]']
#
#  conv2d_210 (Conv2D)            (None, 28, 28, 128)  147584      ['activation_183[0][0]']
#
#  batch_normalization_185 (Batch  (None, 28, 28, 128)  512        ['conv2d_210[0][0]']
#  Normalization)
#
#  add_86 (Add)                   (None, 28, 28, 128)  0           ['batch_normalization_185[0][0]',
#                                                                   'activation_182[0][0]']
#
#  activation_184 (Activation)    (None, 28, 28, 128)  0           ['add_86[0][0]']
#
#  conv2d_211 (Conv2D)            (None, 14, 14, 256)  295168      ['activation_184[0][0]']
#
#  batch_normalization_186 (Batch  (None, 14, 14, 256)  1024       ['conv2d_211[0][0]']
#  Normalization)
#
#  activation_185 (Activation)    (None, 14, 14, 256)  0           ['batch_normalization_186[0][0]']
#
#  conv2d_212 (Conv2D)            (None, 14, 14, 256)  590080      ['activation_185[0][0]']
#
#  batch_normalization_187 (Batch  (None, 14, 14, 256)  1024       ['conv2d_212[0][0]']
#  Normalization)
#
#  conv2d_213 (Conv2D)            (None, 14, 14, 256)  33024       ['activation_184[0][0]']
#
#  add_87 (Add)                   (None, 14, 14, 256)  0           ['batch_normalization_187[0][0]',
#                                                                   'conv2d_213[0][0]']
#
#  activation_186 (Activation)    (None, 14, 14, 256)  0           ['add_87[0][0]']
#
#  conv2d_214 (Conv2D)            (None, 14, 14, 256)  590080      ['activation_186[0][0]']
#
#  batch_normalization_188 (Batch  (None, 14, 14, 256)  1024       ['conv2d_214[0][0]']
#  Normalization)
#
#  activation_187 (Activation)    (None, 14, 14, 256)  0           ['batch_normalization_188[0][0]']
#
#  conv2d_215 (Conv2D)            (None, 14, 14, 256)  590080      ['activation_187[0][0]']
#
#  batch_normalization_189 (Batch  (None, 14, 14, 256)  1024       ['conv2d_215[0][0]']
#  Normalization)
#
#  add_88 (Add)                   (None, 14, 14, 256)  0           ['batch_normalization_189[0][0]',
#                                                                   'activation_186[0][0]']
#
#  activation_188 (Activation)    (None, 14, 14, 256)  0           ['add_88[0][0]']
#
#  conv2d_216 (Conv2D)            (None, 7, 7, 512)    1180160     ['activation_188[0][0]']
#
#  batch_normalization_190 (Batch  (None, 7, 7, 512)   2048        ['conv2d_216[0][0]']
#  Normalization)
#
#  activation_189 (Activation)    (None, 7, 7, 512)    0           ['batch_normalization_190[0][0]']
#
#  conv2d_217 (Conv2D)            (None, 7, 7, 512)    2359808     ['activation_189[0][0]']
#
#  batch_normalization_191 (Batch  (None, 7, 7, 512)   2048        ['conv2d_217[0][0]']
#  Normalization)
#
#  conv2d_218 (Conv2D)            (None, 7, 7, 512)    131584      ['activation_188[0][0]']
#
#  add_89 (Add)                   (None, 7, 7, 512)    0           ['batch_normalization_191[0][0]',
#                                                                   'conv2d_218[0][0]']
#
#  activation_190 (Activation)    (None, 7, 7, 512)    0           ['add_89[0][0]']
#
#  conv2d_219 (Conv2D)            (None, 7, 7, 512)    2359808     ['activation_190[0][0]']
#
#  batch_normalization_192 (Batch  (None, 7, 7, 512)   2048        ['conv2d_219[0][0]']
#  Normalization)
#
#  activation_191 (Activation)    (None, 7, 7, 512)    0           ['batch_normalization_192[0][0]']
#
#  conv2d_220 (Conv2D)            (None, 7, 7, 512)    2359808     ['activation_191[0][0]']
#
#  batch_normalization_193 (Batch  (None, 7, 7, 512)   2048        ['conv2d_220[0][0]']
#  Normalization)
#
#  add_90 (Add)                   (None, 7, 7, 512)    0           ['batch_normalization_193[0][0]',
#                                                                   'activation_190[0][0]']
#
#  activation_192 (Activation)    (None, 7, 7, 512)    0           ['add_90[0][0]']
#
#  global_average_pooling2d_10 (G  (None, 512)         0           ['activation_192[0][0]']
#  lobalAveragePooling2D)
#
#  dense_10 (Dense)               (None, 20)           10260       ['global_average_pooling2d_10[0][
#                                                                  0]']
#
# ==================================================================================================
# Total params: 11,197,588
# Trainable params: 11,189,780
# Non-trainable params: 7,808
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
from tensorflow.keras import layers,models

def residual_block(inputs,filters,downsample=False):
  # The residual block consists of two convolutional layers with batch normalization and ReLU activation.
  conv_1 = layers.Conv2D(filters=filters,kernel_size=(3,3),strides=1 if not downsample else 2,padding='same')(inputs)
  bn_1 = layers.BatchNormalization()(conv_1)
  relu_1 = layers.Activation('relu')(bn_1)

  conv_2 = layers.Conv2D(filters=filters,kernel_size=(3,3),padding='same')(relu_1)
  bn_2 = layers.BatchNormalization()(conv_2)
  # If downsample is True, we apply a 1x1 convolution and downsample the inputs.
  if downsample:
    inputs=layers.Conv2D(filters=filters,kernel_size=(1,1),strides=2,padding='same')(inputs)
  res_add = layers.Add()([bn_2,inputs])
  relu_2 = layers.Activation('relu')(res_add)
  return relu_2


def resnet_18(input_shape, num_classes,activation):
    input_layer = tf.keras.layers.Input(shape=input_shape)

    # Initial convolutional layer
    conv_1 =  layers.Conv2D(64, kernel_size=(7, 7), strides=(2, 2), padding='same')(input_layer)
    bn_1 =  layers.BatchNormalization()(conv_1)
    relu_1 =  layers.Activation('relu')(bn_1)
    max_pool_1 =  layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')(relu_1)

    # Residual blocks
    res_1 = residual_block(inputs=max_pool_1, filters=64)
    res_2 = residual_block(inputs=res_1,filters= 64)
    res_3 = residual_block(inputs=res_2, filters=128, downsample=True)
    res_4 = residual_block(inputs=res_3, filters=128)
    res_5 = residual_block(inputs=res_4, filters=256, downsample=True)
    res_6 = residual_block(inputs=res_5, filters=256)
    res_7 = residual_block(inputs=res_6, filters=512, downsample=True)
    res_8 = residual_block(inputs=res_7, filters=512)

    # Global average pooling and classification layer
    global_avg_pool  =  layers.GlobalAveragePooling2D()(res_8)
    output_layer =  layers.Dense(num_classes, activation=activation)(global_avg_pool)

    model = models.Model(inputs=input_layer, outputs=output_layer)
    return model

# Example usage
input_shape = (224, 224, 3)  # Input shape of the images (assuming 224x224 RGB images)
num_classes = 20  # Number of output classes for the classification task
activation = 'softmax'
resnet18_model = resnet_18(input_shape, num_classes,activation)
resnet18_model.summary()
