# %%
##this version

import tensorflow as tf
from tensorflow.keras import layers, models

# %%
def conv_block(inputs, filters, kernel_size, strides):
    conv_1 = layers.Conv2D(filters=filters, kernel_size=kernel_size, strides=strides, padding='same')(inputs)
    bn_1 = layers.BatchNormalization()(conv_1)
    std_relu = layers.ReLU()(bn_1)  # Use standard ReLU activation
    return std_relu

# %%
def relu6(x):
    return tf.keras.backend.relu(x, max_value=6)

# %%
def depthwise_separable_conv_block(inputs, filters, kernel_size, strides):
    depth_conv = layers.DepthwiseConv2D(kernel_size=kernel_size, strides=strides, padding='same')(inputs)
    depth_conv_bn = layers.BatchNormalization()(depth_conv)
    depth_conv_relu = layers.ReLU()(depth_conv_bn)  # Use standard ReLU activation
    conv_1 = layers.Conv2D(filters, 1, strides=1, padding='same')(conv_1)
    conv_bn = layers.BatchNormalization()(conv_bn)
    conv_relu = relu6(conv_bn)  # Use ReLU6 activation function
    return conv_relu

# %%
def inverted_residual_block(inputs, expansion, filters, kernel_size, strides, use_residual=True):
    input_channels = inputs.shape[-1]

    # Expansion phase
    expand_conv = layers.Conv2D(expansion * input_channels, 1, padding='same')(inputs)
    expand_bn = layers.BatchNormalization()(expand_conv)
    expand_relu6 = relu6(expand_bn)  # Use ReLU6 activation function

    # Depthwise Convolution
    depth_conv_1 = layers.DepthwiseConv2D(kernel_size, strides=strides, padding='same')(expand_relu6)
    depth_bn = layers.BatchNormalization()(depth_conv_1)
    depth_relu6 = relu6(depth_bn)  # Use ReLU6 activation function

    # Projection phase
    project_conv = layers.Conv2D(filters, 1, padding='same')(depth_relu6)
    project_bn = layers.BatchNormalization()(project_conv)

    if use_residual and strides == 1 and input_channels == filters:
        res_add = layers.Add()([inputs, project_bn])
        return res_add

    return project_bn

# %%
def MobileNetV2(input_shape, number_of_class,activation):
    input_layer = tf.keras.Input(shape=input_shape)

    conv1 = conv_block(inputs=input_layer, filters=32,kernel_size= (3,3), strides=2)

    inv_res1 = inverted_residual_block(inputs=conv1, expansion=1, filters=16, kernel_size=(3,3), strides=1)

    inv_res2 = inverted_residual_block(inputs=inv_res1, expansion=6, filters=24, kernel_size=(3,3), strides=2)
    inv_res3 = inverted_residual_block(inputs=inv_res2, expansion=6, filters=24, kernel_size=(3,3), strides=1)

    inv_res4 = inverted_residual_block(inputs=inv_res3, expansion=6, filters=32, kernel_size=(3,3), strides=2)
    inv_res5 = inverted_residual_block(inputs=inv_res4, expansion=6, filters=32, kernel_size=(3,3), strides=1)
    inv_res6 = inverted_residual_block(inputs=inv_res5, expansion=6, filters=32, kernel_size=(3,3), strides=1)

    inv_res7 = inverted_residual_block(inputs=inv_res6, expansion=6, filters=64, kernel_size=(3,3), strides=2)
    inv_res8 = inverted_residual_block(inputs=inv_res7, expansion=6, filters=64, kernel_size=(3,3), strides=1)
    inv_res9 = inverted_residual_block(inputs=inv_res8, expansion=6, filters=64, kernel_size=(3,3), strides=1)
    inv_res10 = inverted_residual_block(inputs=inv_res9, expansion=6, filters=64, kernel_size=(3,3), strides=1)

    inv_res11 = inverted_residual_block(inputs=inv_res10, expansion=6, filters=96, kernel_size=(3,3), strides=1)
    inv_res12 = inverted_residual_block(inputs=inv_res11, expansion=6, filters=96, kernel_size=(3,3), strides=1)
    inv_res13 = inverted_residual_block(inputs=inv_res12, expansion=6, filters=96, kernel_size=(3,3), strides=1)

    inv_res14 = inverted_residual_block(inputs=inv_res13, expansion=6, filters=160, kernel_size=(3,3), strides=2)
    inv_res15 = inverted_residual_block(inputs=inv_res14, expansion=6, filters=160, kernel_size=(3,3), strides=1)
    inv_res16 = inverted_residual_block(inputs=inv_res15, expansion=6, filters=160, kernel_size=(3,3), strides=1)

    inv_res17 = inverted_residual_block(inputs=inv_res16, expansion=6, filters=320, kernel_size=(3,3), strides=1)

    conv2 = conv_block(inputs=inv_res17, filters=1280,kernel_size=(1,1) , strides=1)

    global_avg_pool = layers.GlobalAveragePooling2D()(conv2)

    output_layer = layers.Dense(units=number_of_class, activation=activation)(global_avg_pool)

    model = models.Model(inputs=input_layer, outputs=output_layer)

    return model

# Example usage with 3-channel RGB images and 1000 classes (Imagenet):
input_shape = (224, 224, 3)
number_of_class = 20
activation = 'softmax'

mobilenetv2_model = MobileNetV2(input_shape, number_of_class,activation)
mobilenetv2_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 32  896         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  re_lu (ReLU)                   (None, 112, 112, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 112, 112, 32  1056        ['re_lu[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 112, 112, 32  128        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  tf.nn.relu6 (TFOpLambda)       (None, 112, 112, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  depthwise_conv2d (DepthwiseCon  (None, 112, 112, 32  320        ['tf.nn.relu6[0][0]']
#  v2D)                           )
#
#  batch_normalization_2 (BatchNo  (None, 112, 112, 32  128        ['depthwise_conv2d[0][0]']
#  rmalization)                   )
#
#  tf.nn.relu6_1 (TFOpLambda)     (None, 112, 112, 32  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 112, 112, 16  528         ['tf.nn.relu6_1[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 112, 112, 16  64         ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  conv2d_3 (Conv2D)              (None, 112, 112, 96  1632        ['batch_normalization_3[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 112, 112, 96  384        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  tf.nn.relu6_2 (TFOpLambda)     (None, 112, 112, 96  0           ['batch_normalization_4[0][0]']
#                                 )
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 56, 56, 96)  960         ['tf.nn.relu6_2[0][0]']
#  onv2D)
#
#  batch_normalization_5 (BatchNo  (None, 56, 56, 96)  384         ['depthwise_conv2d_1[0][0]']
#  rmalization)
#
#  tf.nn.relu6_3 (TFOpLambda)     (None, 56, 56, 96)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 56, 56, 24)   2328        ['tf.nn.relu6_3[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 56, 56, 24)  96          ['conv2d_4[0][0]']
#  rmalization)
#
#  conv2d_5 (Conv2D)              (None, 56, 56, 144)  3600        ['batch_normalization_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 56, 56, 144)  576        ['conv2d_5[0][0]']
#  rmalization)
#
#  tf.nn.relu6_4 (TFOpLambda)     (None, 56, 56, 144)  0           ['batch_normalization_7[0][0]']
#
#  depthwise_conv2d_2 (DepthwiseC  (None, 56, 56, 144)  1440       ['tf.nn.relu6_4[0][0]']
#  onv2D)
#
#  batch_normalization_8 (BatchNo  (None, 56, 56, 144)  576        ['depthwise_conv2d_2[0][0]']
#  rmalization)
#
#  tf.nn.relu6_5 (TFOpLambda)     (None, 56, 56, 144)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 56, 56, 24)   3480        ['tf.nn.relu6_5[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 56, 56, 24)  96          ['conv2d_6[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 56, 56, 24)   0           ['batch_normalization_6[0][0]',
#                                                                   'batch_normalization_9[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 56, 56, 144)  3600        ['add[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 56, 56, 144)  576        ['conv2d_7[0][0]']
#  ormalization)
#
#  tf.nn.relu6_6 (TFOpLambda)     (None, 56, 56, 144)  0           ['batch_normalization_10[0][0]']
#
#  depthwise_conv2d_3 (DepthwiseC  (None, 28, 28, 144)  1440       ['tf.nn.relu6_6[0][0]']
#  onv2D)
#
#  batch_normalization_11 (BatchN  (None, 28, 28, 144)  576        ['depthwise_conv2d_3[0][0]']
#  ormalization)
#
#  tf.nn.relu6_7 (TFOpLambda)     (None, 28, 28, 144)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 28, 28, 32)   4640        ['tf.nn.relu6_7[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 28, 28, 32)  128         ['conv2d_8[0][0]']
#  ormalization)
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 192)  6336        ['batch_normalization_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 28, 28, 192)  768        ['conv2d_9[0][0]']
#  ormalization)
#
#  tf.nn.relu6_8 (TFOpLambda)     (None, 28, 28, 192)  0           ['batch_normalization_13[0][0]']
#
#  depthwise_conv2d_4 (DepthwiseC  (None, 28, 28, 192)  1920       ['tf.nn.relu6_8[0][0]']
#  onv2D)
#
#  batch_normalization_14 (BatchN  (None, 28, 28, 192)  768        ['depthwise_conv2d_4[0][0]']
#  ormalization)
#
#  tf.nn.relu6_9 (TFOpLambda)     (None, 28, 28, 192)  0           ['batch_normalization_14[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 32)   6176        ['tf.nn.relu6_9[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 28, 28, 32)  128         ['conv2d_10[0][0]']
#  ormalization)
#
#  add_1 (Add)                    (None, 28, 28, 32)   0           ['batch_normalization_12[0][0]',
#                                                                   'batch_normalization_15[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 192)  6336        ['add_1[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 28, 28, 192)  768        ['conv2d_11[0][0]']
#  ormalization)
#
#  tf.nn.relu6_10 (TFOpLambda)    (None, 28, 28, 192)  0           ['batch_normalization_16[0][0]']
#
#  depthwise_conv2d_5 (DepthwiseC  (None, 28, 28, 192)  1920       ['tf.nn.relu6_10[0][0]']
#  onv2D)
#
#  batch_normalization_17 (BatchN  (None, 28, 28, 192)  768        ['depthwise_conv2d_5[0][0]']
#  ormalization)
#
#  tf.nn.relu6_11 (TFOpLambda)    (None, 28, 28, 192)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 32)   6176        ['tf.nn.relu6_11[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 28, 28, 32)  128         ['conv2d_12[0][0]']
#  ormalization)
#
#  add_2 (Add)                    (None, 28, 28, 32)   0           ['add_1[0][0]',
#                                                                   'batch_normalization_18[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 28, 28, 192)  6336        ['add_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 28, 28, 192)  768        ['conv2d_13[0][0]']
#  ormalization)
#
#  tf.nn.relu6_12 (TFOpLambda)    (None, 28, 28, 192)  0           ['batch_normalization_19[0][0]']
#
#  depthwise_conv2d_6 (DepthwiseC  (None, 14, 14, 192)  1920       ['tf.nn.relu6_12[0][0]']
#  onv2D)
#
#  batch_normalization_20 (BatchN  (None, 14, 14, 192)  768        ['depthwise_conv2d_6[0][0]']
#  ormalization)
#
#  tf.nn.relu6_13 (TFOpLambda)    (None, 14, 14, 192)  0           ['batch_normalization_20[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 14, 14, 64)   12352       ['tf.nn.relu6_13[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 14, 14, 64)  256         ['conv2d_14[0][0]']
#  ormalization)
#
#  conv2d_15 (Conv2D)             (None, 14, 14, 384)  24960       ['batch_normalization_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 14, 14, 384)  1536       ['conv2d_15[0][0]']
#  ormalization)
#
#  tf.nn.relu6_14 (TFOpLambda)    (None, 14, 14, 384)  0           ['batch_normalization_22[0][0]']
#
#  depthwise_conv2d_7 (DepthwiseC  (None, 14, 14, 384)  3840       ['tf.nn.relu6_14[0][0]']
#  onv2D)
#
#  batch_normalization_23 (BatchN  (None, 14, 14, 384)  1536       ['depthwise_conv2d_7[0][0]']
#  ormalization)
#
#  tf.nn.relu6_15 (TFOpLambda)    (None, 14, 14, 384)  0           ['batch_normalization_23[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 14, 14, 64)   24640       ['tf.nn.relu6_15[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 14, 14, 64)  256         ['conv2d_16[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 14, 14, 64)   0           ['batch_normalization_21[0][0]',
#                                                                   'batch_normalization_24[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 14, 14, 384)  24960       ['add_3[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 14, 14, 384)  1536       ['conv2d_17[0][0]']
#  ormalization)
#
#  tf.nn.relu6_16 (TFOpLambda)    (None, 14, 14, 384)  0           ['batch_normalization_25[0][0]']
#
#  depthwise_conv2d_8 (DepthwiseC  (None, 14, 14, 384)  3840       ['tf.nn.relu6_16[0][0]']
#  onv2D)
#
#  batch_normalization_26 (BatchN  (None, 14, 14, 384)  1536       ['depthwise_conv2d_8[0][0]']
#  ormalization)
#
#  tf.nn.relu6_17 (TFOpLambda)    (None, 14, 14, 384)  0           ['batch_normalization_26[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 14, 14, 64)   24640       ['tf.nn.relu6_17[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 14, 14, 64)  256         ['conv2d_18[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 14, 14, 64)   0           ['add_3[0][0]',
#                                                                   'batch_normalization_27[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 14, 14, 384)  24960       ['add_4[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 14, 14, 384)  1536       ['conv2d_19[0][0]']
#  ormalization)
#
#  tf.nn.relu6_18 (TFOpLambda)    (None, 14, 14, 384)  0           ['batch_normalization_28[0][0]']
#
#  depthwise_conv2d_9 (DepthwiseC  (None, 14, 14, 384)  3840       ['tf.nn.relu6_18[0][0]']
#  onv2D)
#
#  batch_normalization_29 (BatchN  (None, 14, 14, 384)  1536       ['depthwise_conv2d_9[0][0]']
#  ormalization)
#
#  tf.nn.relu6_19 (TFOpLambda)    (None, 14, 14, 384)  0           ['batch_normalization_29[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 14, 14, 64)   24640       ['tf.nn.relu6_19[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 14, 14, 64)  256         ['conv2d_20[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 14, 14, 64)   0           ['add_4[0][0]',
#                                                                   'batch_normalization_30[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 14, 14, 384)  24960       ['add_5[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 14, 14, 384)  1536       ['conv2d_21[0][0]']
#  ormalization)
#
#  tf.nn.relu6_20 (TFOpLambda)    (None, 14, 14, 384)  0           ['batch_normalization_31[0][0]']
#
#  depthwise_conv2d_10 (Depthwise  (None, 14, 14, 384)  3840       ['tf.nn.relu6_20[0][0]']
#  Conv2D)
#
#  batch_normalization_32 (BatchN  (None, 14, 14, 384)  1536       ['depthwise_conv2d_10[0][0]']
#  ormalization)
#
#  tf.nn.relu6_21 (TFOpLambda)    (None, 14, 14, 384)  0           ['batch_normalization_32[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 14, 14, 96)   36960       ['tf.nn.relu6_21[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 14, 14, 96)  384         ['conv2d_22[0][0]']
#  ormalization)
#
#  conv2d_23 (Conv2D)             (None, 14, 14, 576)  55872       ['batch_normalization_33[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 14, 14, 576)  2304       ['conv2d_23[0][0]']
#  ormalization)
#
#  tf.nn.relu6_22 (TFOpLambda)    (None, 14, 14, 576)  0           ['batch_normalization_34[0][0]']
#
#  depthwise_conv2d_11 (Depthwise  (None, 14, 14, 576)  5760       ['tf.nn.relu6_22[0][0]']
#  Conv2D)
#
#  batch_normalization_35 (BatchN  (None, 14, 14, 576)  2304       ['depthwise_conv2d_11[0][0]']
#  ormalization)
#
#  tf.nn.relu6_23 (TFOpLambda)    (None, 14, 14, 576)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 14, 14, 96)   55392       ['tf.nn.relu6_23[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 14, 14, 96)  384         ['conv2d_24[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 14, 14, 96)   0           ['batch_normalization_33[0][0]',
#                                                                   'batch_normalization_36[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 14, 14, 576)  55872       ['add_6[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 14, 14, 576)  2304       ['conv2d_25[0][0]']
#  ormalization)
#
#  tf.nn.relu6_24 (TFOpLambda)    (None, 14, 14, 576)  0           ['batch_normalization_37[0][0]']
#
#  depthwise_conv2d_12 (Depthwise  (None, 14, 14, 576)  5760       ['tf.nn.relu6_24[0][0]']
#  Conv2D)
#
#  batch_normalization_38 (BatchN  (None, 14, 14, 576)  2304       ['depthwise_conv2d_12[0][0]']
#  ormalization)
#
#  tf.nn.relu6_25 (TFOpLambda)    (None, 14, 14, 576)  0           ['batch_normalization_38[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 14, 14, 96)   55392       ['tf.nn.relu6_25[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 14, 14, 96)  384         ['conv2d_26[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 14, 14, 96)   0           ['add_6[0][0]',
#                                                                   'batch_normalization_39[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 14, 14, 576)  55872       ['add_7[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 14, 14, 576)  2304       ['conv2d_27[0][0]']
#  ormalization)
#
#  tf.nn.relu6_26 (TFOpLambda)    (None, 14, 14, 576)  0           ['batch_normalization_40[0][0]']
#
#  depthwise_conv2d_13 (Depthwise  (None, 7, 7, 576)   5760        ['tf.nn.relu6_26[0][0]']
#  Conv2D)
#
#  batch_normalization_41 (BatchN  (None, 7, 7, 576)   2304        ['depthwise_conv2d_13[0][0]']
#  ormalization)
#
#  tf.nn.relu6_27 (TFOpLambda)    (None, 7, 7, 576)    0           ['batch_normalization_41[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 7, 7, 160)    92320       ['tf.nn.relu6_27[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 7, 7, 160)   640         ['conv2d_28[0][0]']
#  ormalization)
#
#  conv2d_29 (Conv2D)             (None, 7, 7, 960)    154560      ['batch_normalization_42[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 7, 7, 960)   3840        ['conv2d_29[0][0]']
#  ormalization)
#
#  tf.nn.relu6_28 (TFOpLambda)    (None, 7, 7, 960)    0           ['batch_normalization_43[0][0]']
#
#  depthwise_conv2d_14 (Depthwise  (None, 7, 7, 960)   9600        ['tf.nn.relu6_28[0][0]']
#  Conv2D)
#
#  batch_normalization_44 (BatchN  (None, 7, 7, 960)   3840        ['depthwise_conv2d_14[0][0]']
#  ormalization)
#
#  tf.nn.relu6_29 (TFOpLambda)    (None, 7, 7, 960)    0           ['batch_normalization_44[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 7, 7, 160)    153760      ['tf.nn.relu6_29[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 7, 7, 160)   640         ['conv2d_30[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 7, 7, 160)    0           ['batch_normalization_42[0][0]',
#                                                                   'batch_normalization_45[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 7, 7, 960)    154560      ['add_8[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 7, 7, 960)   3840        ['conv2d_31[0][0]']
#  ormalization)
#
#  tf.nn.relu6_30 (TFOpLambda)    (None, 7, 7, 960)    0           ['batch_normalization_46[0][0]']
#
#  depthwise_conv2d_15 (Depthwise  (None, 7, 7, 960)   9600        ['tf.nn.relu6_30[0][0]']
#  Conv2D)
#
#  batch_normalization_47 (BatchN  (None, 7, 7, 960)   3840        ['depthwise_conv2d_15[0][0]']
#  ormalization)
#
#  tf.nn.relu6_31 (TFOpLambda)    (None, 7, 7, 960)    0           ['batch_normalization_47[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 7, 7, 160)    153760      ['tf.nn.relu6_31[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 7, 7, 160)   640         ['conv2d_32[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 7, 7, 160)    0           ['add_8[0][0]',
#                                                                   'batch_normalization_48[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 7, 7, 960)    154560      ['add_9[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 7, 7, 960)   3840        ['conv2d_33[0][0]']
#  ormalization)
#
#  tf.nn.relu6_32 (TFOpLambda)    (None, 7, 7, 960)    0           ['batch_normalization_49[0][0]']
#
#  depthwise_conv2d_16 (Depthwise  (None, 7, 7, 960)   9600        ['tf.nn.relu6_32[0][0]']
#  Conv2D)
#
#  batch_normalization_50 (BatchN  (None, 7, 7, 960)   3840        ['depthwise_conv2d_16[0][0]']
#  ormalization)
#
#  tf.nn.relu6_33 (TFOpLambda)    (None, 7, 7, 960)    0           ['batch_normalization_50[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 7, 7, 320)    307520      ['tf.nn.relu6_33[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 7, 7, 320)   1280        ['conv2d_34[0][0]']
#  ormalization)
#
#  conv2d_35 (Conv2D)             (None, 7, 7, 1280)   410880      ['batch_normalization_51[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 7, 7, 1280)  5120        ['conv2d_35[0][0]']
#  ormalization)
#
#  re_lu_1 (ReLU)                 (None, 7, 7, 1280)   0           ['batch_normalization_52[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1280)        0           ['re_lu_1[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 20)           25620       ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 2,301,844
# Trainable params: 2,267,668
# Non-trainable params: 34,176
# __________________________________________________________________________________________________
